# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
current_datetime = datetime.now()

# %%
current = pd.read_excel(r'C:\Users\Trenkin.Sergey\Desktop\ТОП товары для мониторинга 28.11.2023.xlsx', sheet_name='Индикаторы') # указывать текущий файл мониторинга
previous = pd.read_csv(r'C:\Users\Trenkin.Sergey\Desktop\trenkinsv\проекты\мониторинг индикаторов\datalens\page_1.csv', sep=';')

# %%
tg = current['ТГ'].tolist()
tn = []
for t in tg:
    t = t.split(' ')
    tn.append(t[0])

# %%
current.columns, previous.columns
# Out:
# (Index(['Ссылка', 'Наименование изделия', 'ТГ', 'Площадка', 'Бренд', 'Проба',
#         'Цена до применения промокодов и бонусных рублей 21.11.2023',
#         'Вес 21.11.23', 'Вес 28.11.23', 'Размер', 'Скидка 21.11.23',
#         'Наименование вставки', 'Цена за грамм изделия 21.11.2023',
#         'Итоговая цена за изделие с промокодами и бонусными рублями 21.11.2023',
#         'Рейтинг 21.11.2023 (по цене за штуку, тяжеловесы по цене за грамм)',
#         'Цена до применения промокодов и бонусных рублей 28.11.2023',
#         'Скидка 28.11.23', 'Цена за грамм изделия 28.11.2023',
#         'Итоговая цена за изделие с промокодами и бонусными рублями 28.11.2023',
#         'Изменения в цене ЗА ИЗДЕЛИЕ', 'Рейтинг 28.11.2023'],
#        dtype='object'),
#  Index(['Ссылка', 'Наименование изделия', 'ТН', 'ТГ', 'Площадка', 'Бренд',
#         'Проба', 'Цена до применения промокодов и бонусных рублей', 'Вес ',
#         'Размер', 'Скидка', 'Наименование вставки', 'Цена за грамм изделия',
#         'Итоговая цена за изделие с промокодами и бонусными рублями ',
#         'Рейтинг по цене за штуку ', 'Дата мониторинга'],
#        dtype='object'))

# %%
current = current.drop(columns=['Цена до применения промокодов и бонусных рублей 21.11.2023',
        'Вес 21.11.23', 'Скидка 21.11.23', 'Цена за грамм изделия 21.11.2023',
        'Итоговая цена за изделие с промокодами и бонусными рублями 21.11.2023',
        'Рейтинг 21.11.2023 (по цене за штуку, тяжеловесы по цене за грамм)',
        'Изменения в цене ЗА ИЗДЕЛИЕ'], axis=1)

# %%
current.insert(2, 'ТН', tn)

# %%
current.head()
# Out:
#                                               Ссылка  \
# 0  https://www.585zolotoy.ru/catalog/products/266...
# 1  https://www.ozon.ru/product/argenterika-koltso...
# 2  https://www.wildberries.ru/catalog/9853895/det...
# 3  https://www.585zolotoy.ru/catalog/products/200...
# 4  https://www.wildberries.ru/catalog/165920670/d...
#
#        Наименование изделия  ТН               ТГ    Площадка        Бренд  \
# 0            Кольцо, каучук  БК        БК КОЛЬЦА  585ZOLOTOY          NaN
# 1            Кольцо, каучук  БК        БК КОЛЬЦА        OZON  Аргентерика
# 2            Кольцо, каучук  БК        БК КОЛЬЦА          WB        АТОЛЛ
# 3  Кольцо обручальное 3 мм.  БК  БК КОЛЬЦА ОБРУЧ  585ZOLOTOY       TALANT
# 4  Кольцо обручальное 3 мм.  БК  БК КОЛЬЦА ОБРУЧ          WB       Юверос
#
#    Проба  Вес 28.11.23  Размер Наименование вставки  \
# 0    585          0.59    17.0                  NaN
# 1    585          0.55    17.0                  NaN
# 2    585          0.70    17.0                  NaN
# 3    585          1.42    17.5                  NaN
# 4    585          1.36    17.5                  NaN
#
#   Цена до применения промокодов и бонусных рублей 28.11.2023 Скидка 28.11.23  \
# 0                                             3800,0                     0,7
# 1                                               4079                       1
# 2                                             4283,0                       1
# 3                                            12464,0                     1,0
# 4                                             9149,0                       1
#
#    Цена за грамм изделия 28.11.2023  \
# 0                       4508.474576
# 1                       7416.363636
# 2                       6118.571429
# 3                       8777.464789
# 4                       6727.205882
#
#    Итоговая цена за изделие с промокодами и бонусными рублями 28.11.2023  \
# 0                                             2660.0
# 1                                             4079.0
# 2                                             4283.0
# 3                                            12464.0
# 4                                             9149.0
#
#    Рейтинг 28.11.2023
# 0                   1
# 1                   2
# 2                   3
# 3                   5
# 4                   1

# %%
current.columns = ['Ссылка', 'Наименование изделия', 'ТН', 'ТГ', 'Площадка', 'Бренд',
       'Проба', 'Вес ', 'Размер', 'Наименование вставки', 'Цена до применения промокодов и бонусных рублей', 'Скидка',
       'Цена за грамм изделия',
       'Итоговая цена за изделие с промокодами и бонусными рублями ', 'Рейтинг по цене за штуку ']

# %%
previous.head()
# Out:
#                                               Ссылка  \
# 0  https://www.585zolotoy.ru/catalog/products/266...
# 1  https://www.ozon.ru/product/novozoloto-koltso-...
# 2  https://www.wildberries.ru/catalog/9853895/det...
# 3  https://www.585zolotoy.ru/catalog/products/200...
# 4  https://www.wildberries.ru/catalog/165920670/d...
#
#        Наименование изделия  ТН               ТГ    Площадка       Бренд  \
# 0            Кольцо, каучук  БК        БК КОЛЬЦА  585ZOLOTOY         NaN
# 1            Кольцо, каучук  БК        БК КОЛЬЦА        OZON  NOVOZOLOTO
# 2            Кольцо, каучук  БК        БК КОЛЬЦА          WB       АТОЛЛ
# 3  Кольцо обручальное 3 мм.  БК  БК КОЛЬЦА ОБРУЧ  585ZOLOTOY         NaN
# 4  Кольцо обручальное 3 мм.  БК  БК КОЛЬЦА ОБРУЧ          WB      Юверос
#
#    Проба Цена до применения промокодов и бонусных рублей  Вес  Размер Скидка  \
# 0    585                                           4 258  0,59     17      1
# 1    585                                           5 695  1,16     17      1
# 2    585                                           5 016   0,7     17      1
# 3    585                                          13 235  1,42   17,5      1
# 4    585                                          12 135  1,36   17,5      1
#
#   Наименование вставки Цена за грамм изделия  \
# 0                  NaN                 7 217
# 1                  NaN                 4 909
# 2                  NaN                 7 166
# 3                  NaN                 9 321
# 4                  NaN                 8 923
#
#   Итоговая цена за изделие с промокодами и бонусными рублями   \
# 0                                              4 258
# 1                                              5 695
# 2                                              5 016
# 3                                             13 235
# 4                                             12 135
#
#    Рейтинг по цене за штуку  Дата мониторинга
# 0                          1       19.10.2023
# 1                          3       19.10.2023
# 2                          2       19.10.2023
# 3                          5       19.10.2023
# 4                          3       19.10.2023

# %%
current['Дата мониторинга'] = current_datetime
current['Дата мониторинга'] = pd.to_datetime(current['Дата мониторинга'].apply(lambda x: x.strftime("%Y-%m-%d")))

# %%
a = previous.columns

# %%
a = a.tolist()

# %%
current = current[a]

# %%
result = pd.concat([previous, current], ignore_index=True)

# %%
result.tail()
# Out:
#                                                  Ссылка  \
# 1898  https://www.wildberries.ru/catalog/95822010/de...
# 1899  https://www.585zolotoy.ru/catalog/products/836...
# 1900  https://www.ozon.ru/product/poemiq-tsepochka-z...
# 1901  https://www.wildberries.ru/catalog/50838499/de...
# 1902  https://spb.sunlight.net/catalog/chains_79438....
#
#                  Наименование изделия  ТН       ТГ    Площадка  \
# 1898              Цепь Лав пуст с а/г  ЦБ  ЦБ ЦЕПИ          WB
# 1899  Цепь Панцирь двойной с а/г пуст  ЦБ  ЦБ ЦЕПИ  585ZOLOTOY
# 1900  Цепь Панцирь двойной с а/г пуст  ЦБ  ЦБ ЦЕПИ        OZON
# 1901  Цепь Панцирь двойной с а/г пуст  ЦБ  ЦБ ЦЕПИ          WB
# 1902  Цепь Панцирь двойной с а/г пуст  ЦБ  ЦБ ЦЕПИ    SUNLIGHT
#
#                                Бренд  Проба  \
# 1898                       REDzoloto    585
# 1899                             NaN    585
# 1900                          poemiq    585
# 1901                       REDzoloto    585
# 1902  МОСКОВСКИЙ ЦЕПЕВЯЗАЛЬНЫЙ ЗАВОД    585
#
#      Цена до применения промокодов и бонусных рублей  Вес  Размер Скидка  \
# 1898                                         13456,0  1.89   45.0      1
# 1899                                         11096,0  1.77   40.0    0,9
# 1900                                            5869  1.09   35.0      1
# 1901                                         15387,0  1.99   45.0      1
# 1902                                           19670  2.15   45.0    0,7
#
#      Наименование вставки Цена за грамм изделия  \
# 1898                  NaN            7119.57672
# 1899                  NaN           5642.033898
# 1900                  NaN            5384.40367
# 1901                  NaN           7732.160804
# 1902                  NaN           6357.674419
#
#      Итоговая цена за изделие с промокодами и бонусными рублями   \
# 1898                                            13456.0
# 1899                                             9986.4
# 1900                                             5869.0
# 1901                                            15387.0
# 1902                                            13669.0
#
#       Рейтинг по цене за штуку      Дата мониторинга
# 1898                          3  2023-11-28 00:00:00
# 1899                          2  2023-11-28 00:00:00
# 1900                          1  2023-11-28 00:00:00
# 1901                          4  2023-11-28 00:00:00
# 1902                          3  2023-11-28 00:00:00

# %%
result.to_csv('page_1.csv')
